# %%
import pandas as pd
import os

# %%
# 读取数据
df=pd.read_csv(os.path.join(os.pardir, "logging", "log.csv"))
df
# Out:
#         data_id  is_convert fusion_sequence   free_sequence  is_valid  \
# 0           178           1              SN              SN         1
# 1           354           1              SN              SN         1
# 2           894           1              SN              SN         1
# 3          1020           1            SNSC  SNSCSCSCSCSCSC         1
# 4          1021           1              SN              SN         1
# ...         ...         ...             ...             ...       ...
# 923741  2818659           1            SNSC            SNSC         1
# 923742  2818660           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923743  2818661           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923744  2818662           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923745  2818663           1        SNSCSJSC    SNSCSCSCSJSC         1
#
#        error_code
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...

# %%
# 将data_id在[]
len(df)
# Out:
# 923746

# %%
df.items
# Out:
# <bound method DataFrame.items of         data_id  is_convert fusion_sequence   free_sequence  is_valid  \
# 0           178           1              SN              SN         1
# 1           354           1              SN              SN         1
# 2           894           1              SN              SN         1
# 3          1020           1            SNSC  SNSCSCSCSCSCSC         1
# 4          1021           1              SN              SN         1
# ...         ...         ...             ...             ...       ...
# 923741  2818659           1            SNSC            SNSC         1
# 923742  2818660           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923743  2818661           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923744  2818662           1        SNSCSJSC    SNSCSCSCSJSC         1
# 923745  2818663           1        SNSCSJSC    SNSCSCSCSJSC         1
#
#        error_code
# 0             NaN
# 1             NaN
# 2             NaN
# ...

# %%
df.columns
# Out:
# Index(['data_id', 'is_convert', 'fusion_sequence', 'free_sequence', 'is_valid',
#        'error_code'],
#       dtype='object')
